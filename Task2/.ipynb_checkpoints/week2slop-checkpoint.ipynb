# %% [markdown]
# $$ \begin{gather}
# \sum_{k=0}^{\infty}\frac{1}{4k^2-1}=\frac{1}{2} \\
#     \int_{0}^{\pi}e^{ix}dx=2i
#     \end{gather}
#     $$

# %%
from math import atan2, degrees

x = float(input("The x value is: "))
y = float(input("The y value is: ")) 
ang = math.atan2(x,y)
if ang<math.pi/2 and ang>0:
 print("quad juan")
elif ang<0 and ang>-math.pi/2:
 print("quad dos")
elif ang<-math.pi/2:
 print("quad tres")
elif ang>math.pi/2 and ang<math.pi:
 print("quad quatro")
   
print(ang)

# atan2 writes the quadarant
# Out:
# The x value is:  -1
# The y value is:  2
# quad dos
# -0.4636476090008061

# %%
x = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]

x.append(0.51)
x.pop(3) 
print(x[6])
# 1.46 is located at index 1
j = x[2:7:2]
print(j)
sum =0
for i in j:
    sum+=i
print(sum)
# Out:
# 1.97
# [1.41, 0.98, 1.97]
# 4.359999999999999

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
night1 = set(night1)
night2 = set(night2)
intersec = set.intersection(night1, night2)
intersec = list(intersec)
if 5 in intersec:
    print("5 is present in the set")
else:
    print("5 is not in the set")
if 5 in night1:
    print("5 is in the night1 set")
# Out:
# 5 is not in the set
# 5 is in the night1 set

# %%
import numpy as np
l = np.random.normal(0,1.4,100000)
sigma = np.std(l, ddof=1)
print(sigma)
# Out:
# 1.401195461823897

# %%
a = 1
b = 2
for i in range(98):
  a, b = b, a+b 
print(b)
# Out:
# 573147844013817084101
