# %%
import numpy as np
from matplotlib.pyplot import figure, show
from matplotlib.patches import ELlipse
Nx = 400
Ny = 300
data = np.random.random((Ny, Nx))


fig, ax = plt.subplots()
ax.imshow(data, interpolation = 'none', origin='lower', cmap='gray')

center = (Nx/2, Ny/2)
width = 100*2
height = 50*2
angle = 30

ellipse = Ellipse(xy=center, width=width, height=height, angle=angle, edgecolor="red", faceecolor="none",lw =2)

ax.add_patch(ellipse)

ax.set_title("ELLIPSE")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 from matplotlib.pyplot import figure, show
# ----> 3 from matplotlib.patches import ELlipse
#       4 Nx = 400
#       5 Ny = 300
#
# ImportError: cannot import name 'ELlipse' from 'matplotlib.patches' (/Software/users/modules/9/software/anaconda3/2025.06/lib/python3.13/site-packages/matplotlib/patches.py)
