# %% [markdown]
# Answers for Week 1
#
# * Name: Andrei Hreniuc
# * Username: ahreniuc
# * Student s-number: S6403832
# * Group (AS1, etc.): AS5

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![J_Geils_Band_1973.JPG](attachment:aad89501-fff9-4b6c-a48e-4c1f2cb28f90.JPG)

# %%
fact = 6
fact *= 5
fact *= 4
fact *= 3
fact *= 2
fact *= 1
print(fact)
# Out:
# 720

# %%
h = 6.62e-34
c = 299792458
lamb= 2.42e28

E = h*c/lamb

print(E)
# Out:
# 8.200934181652892e-54

# %%
moon = 7.342e22
earth = 5.9722e24
dist = 385e6
G = 6.67e-11

F = G*moon*earth/(dist*dist)
print(F)
# Out:
# 1.973118180522854e+20

# %% [markdown]
# ![Screenshot from 2026-02-10 14-08-38.png](attachment:06d68c1e-d781-4337-9247-680d2651eb39.png)

# %% [markdown]
# ![Screenshot from 2026-02-10 14-15-28.png](attachment:c3622621-b237-418c-98e3-86d81076eb78.png)

# %% [markdown]
# the dot represents the directory from which the files are opened. (in this case, the HOME directory)
